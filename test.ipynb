# %%
from src import solve, read_data
import numpy as np
import pandas as pd

data = pd.DataFrame(np.array([
        ['A', 1, 2, 8, 8, 8],
        # ['qq', 1, 2, 0, 0, 0],
        ['B', 1, 4, 2, 2, 2],
        ['C', 1, 3, 4, 4, 4],
        ['D', 2, 4, 4, 4, 4],
        ['E', 2, 5, 4, 4, 4],
        ['F', 4, 6, 5, 5, 5],
        ['G', 3, 6, 13, 13, 13],
        ['H', 5, 7, 3, 3, 3],
        ['I', 6, 7, 5, 5, 5]
        ]), 
        columns=['name', 'src', 'dst', 'tc', 'tm', 'tp'])

q = solve(data)
# Out:
# Całkowity czas przedsięwzięcia z prawdopodobieństwem 90% wyniesie nie więcej niż 22.0.
# Wariancja wyniosła 0.
# Ścieżka krytyczna nr 1
# ['A' 'D' 'F']
# Ścieżka krytyczna nr 2
# ['C' 'G' 'I']

# %%
from src import solve, read_data
import numpy as np
import pandas as pd

data = pd.DataFrame(np.array([
        ['A', 1, 2, 8, 8, 8],
        # ['qq', 1, 2, 0, 0, 0],
        ['B', 1, 4, 2, 2, 2],
        ['C', 1, 3, 4, 4, 4],
        ['D', 2, 4, 4, 4, 4],
        ['E', 2, 5, 4, 4, 4],
        ['F', 4, 60, 5, 5, 5],
        ['G', 3, 60, 13, 13, 13],
        ['Gqqq', 60, 6, 0, 0, 0],
        ['H', 5, 7, 3, 3, 3],
        ['I', 6, 7, 5, 5, 5]
        ]), 
        columns=['name', 'src', 'dst', 'tc', 'tm', 'tp'])

q = solve(data)
# Out:
# Całkowity czas przedsięwzięcia z prawdopodobieństwem 90% wyniesie nie więcej niż 22.0.
# Wariancja wyniosła 0.
# Ścieżka krytyczna nr 1
# ['A' 'D' 'F']
# Ścieżka krytyczna nr 2
# ['C' 'G' 'I']
